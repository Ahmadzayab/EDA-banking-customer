# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt



df = pd.read_csv("Semester Project Dataset_1.csv")
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
fig, ax = plt.subplots()
sns.lineplot(data = df, x='Geography', y='CreditScore', dashes = False, ci=None )
    ax.text(0.5, 0.5, '2020CDCS1', transform=ax.transAxes,
        fontsize=40, color='black', alpha=0.5,
        ha='center', va='center', rotation=30)
# Out:
#   Input In [61]
#     ax.text(0.5, 0.5, '2020CDCS1', transform=ax.transAxes,
#     ^
# IndentationError: unexpected indent

# %%
fig, ax = plt.subplots()
plt.scatter(df.index,df['Age'])
ax.text(0.5, 0.5, '2020cs629', transform=ax.transAxes,
        fontsize=40, color='black', alpha=0.5,
        ha='center', va='center', rotation=30)
# Out:
# Text(0.5, 0.5, '2020cs629')

# %%
fig, ax = plt.subplots()
plt.hist(df['Age'])
ax.text(0.5, 0.5, '2020cs629', transform=ax.transAxes,
        fontsize=40, color='black', alpha=0.5,
        ha='center', va='center', rotation=30)
# Out:
# Text(0.5, 0.5, '2020cs629')

# %%
fig, ax = plt.subplots()
df[df['CreditScore'] < 700].plot.hexbin(x='CreditScore', y='Age', gridsize=15)
ax.text(0.5, 0.5, '2020cs629', transform=ax.transAxes,
        fontsize=40, color='black', alpha=0.5,
        ha='center', va='center', rotation=30)
# Out:
# Text(0.5, 0.5, '2020cs629')

# %%
 sns.relplot(data = tipsData, x='CreditScore', y='' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 sns.relplot(data = tipsData, x='CreditScore', y='' )
#
# File ~\jupiter\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
sns.catplot(data = df,kind='bar', x='Geography', y='CreditScore', hue='Gender')

# %%
fig, ax = plt.subplots()
sns.catplot(data = df,kind='box', x='Gender', y='CreditScore', hue='Geography')
ax.text(0.5, 0.5, '2020cs629', transform=ax.transAxes,
        fontsize=40, color='black', alpha=0.5,
        ha='center', va='center', rotation=30)
# Out:
# Text(0.5, 0.5, '2020cs629')

# %%
sns.relplot(data = df, x='Balance', y='CreditScore', hue='Geography',size='Gender' )

# %%
sns.lmplot(data=df, x="Balance", y="CreditScore", col="Geography", hue="Gender")

# %%
sns.catplot(data=df, kind="swarm", x="Geography", y="CreditScore", hue="Gender",sizes=(10, 200))
# Out:
# C:\Users\Ahmad Zayab\jupiter\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 83.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ahmad Zayab\jupiter\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ahmad Zayab\jupiter\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
